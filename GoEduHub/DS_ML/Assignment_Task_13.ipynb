# %% [markdown]
# # **Q - Data Science: Exploratory Data Analysis (EDA) of Titanic Survival Problem using Seaborn**
#
# Exploratory Data Analysis (EDA) of Titanic Survival Problem.To do the same we will use the Pandas, Seaborn and Matplotlib library.
#
# Dataset contains the details of the passengers who had boarded the ship.
#
# Dataset can be downloaded from [Kaggle.](https://www.kaggle.com/dejavu23/titanic-eda-to-ml-beginner)

# %% [markdown]
# **Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df_test = pd.read_csv("test.csv")
df_train = pd.read_csv("train.csv")

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# (Of all passengers in df_train, how many survived, how many died ?)

# %%
sns.countplot(x='Survived', data=df_train);

# %%
print(df_train.Survived.sum()/df_train.Survived.count())
# Out:
# 0.3838383838383838

# %% [markdown]
# more people died than survived (38% survived)
#
# -> base model : no survivors
#
# submission : 0.627 accuracy

# %% [markdown]
# **Sex: Female more likely to survive than male**

# %%
df_train.groupby(['Survived','Sex'])['Survived'].count()
# Out:
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Survived, dtype: int64

# %%
sns.catplot(x='Sex', col='Survived', kind='count', data=df_train);

# %%
print("% of women survived: " , df_train[df_train.Sex == 'female'].Survived.sum()/df_train[df_train.Sex == 'female'].Survived.count())
print("% of men survived:   " , df_train[df_train.Sex == 'male'].Survived.sum()/df_train[df_train.Sex == 'male'].Survived.count())
# Out:
# % of women survived:  0.7420382165605095
# % of men survived:    0.18890814558058924

# %%
f,ax=plt.subplots(1,2,figsize=(16,7))
df_train['Survived'][df_train['Sex']=='male'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
df_train['Survived'][df_train['Sex']=='female'].value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
ax[0].set_title('Survived (male)')
ax[1].set_title('Survived (female)')

plt.show()

# %% [markdown]
# **Passenger Class : Survival rate decreases with Pclass**

# %%
pd.crosstab(df_train.Pclass, df_train.Survived, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_0641d_row0_col0,#T_0641d_row1_col1,#T_0641d_row1_col2{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_0641d_row0_col1{
#             background-color:  #ffce00;
#             color:  #000000;
#         }#T_0641d_row0_col2{
#             background-color:  #fff400;
#             color:  #000000;
#         }#T_0641d_row1_col0{
#             background-color:  #fff600;
#             color:  #000000;
#         }#T_0641d_row2_col0{
#             background-color:  #ff6000;
#             color:  #000000;
#         }#T_0641d_row2_col1{
#             background-color:  #ffdf00;
#             color:  #000000;
#         }#T_0641d_row2_col2{
#             background-color:  #ff9000;
#             color:  #000000;
#         }#T_0641d_row3_col0,#T_0641d_row3_col1,#T_0641d_row3_col2{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_0641d_" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0641d_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_0641d_row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_0641d_row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_0641d_row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_0641d_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_0641d_row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_0641d_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_0641d_row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_0641d_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_0641d_row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_0641d_row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_0641d_row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_0641d_level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_0641d_row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_0641d_row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_0641d_row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
print("% of survivals in") 
print("Pclass=1 : ", df_train.Survived[df_train.Pclass == 1].sum()/df_train[df_train.Pclass == 1].Survived.count())
print("Pclass=2 : ", df_train.Survived[df_train.Pclass == 2].sum()/df_train[df_train.Pclass == 2].Survived.count())
print("Pclass=3 : ", df_train.Survived[df_train.Pclass == 3].sum()/df_train[df_train.Pclass == 3].Survived.count())
# Out:
# % of survivals in
# Pclass=1 :  0.6296296296296297
# Pclass=2 :  0.47282608695652173
# Pclass=3 :  0.24236252545824846

# %%
sns.catplot('Pclass','Survived', kind='point', data=df_train);

# %% [markdown]
# Almost all women in Pclass 1 and 2 survived and nearly all men in Pclass 2 and 3 died

# %%
pd.crosstab([df_train.Sex, df_train.Survived], df_train.Pclass, margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_e9247_row0_col0,#T_e9247_row0_col1,#T_e9247_row0_col3,#T_e9247_row3_col2{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_e9247_row0_col2,#T_e9247_row1_col2{
#             background-color:  #fff100;
#             color:  #000000;
#         }#T_e9247_row1_col0{
#             background-color:  #ff9600;
#             color:  #000000;
#         }#T_e9247_row1_col1{
#             background-color:  #ffa300;
#             color:  #000000;
#         }#T_e9247_row1_col3{
#             background-color:  #ffcf00;
#             color:  #000000;
#         }#T_e9247_row2_col0{
#             background-color:  #ffa700;
#             color:  #000000;
#         }#T_e9247_row2_col1,#T_e9247_row2_col3{
#             background-color:  #ff8500;
#             color:  #000000;
#         }#T_e9247_row2_col2{
#             background-color:  #ff6e00;
#             color:  #000000;
#         }#T_e9247_row3_col0{
#             background-color:  #ffcd00;
#             color:  #000000;
#         }#T_e9247_row3_col1{
#             background-color:  #fff000;
#             color:  #000000;
#         }#T_e9247_row3_col3{
#             background-color:  #fff700;
#             color:  #000000;
#         }#T_e9247_row4_col0,#T_e9247_row4_col1,#T_e9247_row4_col2,#T_e9247_row4_col3{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_e9247_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9247_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#                         <th id="T_e9247_level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_e9247_row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_e9247_row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_e9247_row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_e9247_row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_e9247_level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_e9247_row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_e9247_row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_e9247_row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_e9247_row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_e9247_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#                         <th id="T_e9247_level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_e9247_row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_e9247_row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_e9247_row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_e9247_row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_e9247_level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_e9247_row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_e9247_row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_e9247_row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_e9247_row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_e9247_level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_e9247_level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_e9247_row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_e9247_row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_e9247_row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_e9247_row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.catplot('Pclass','Survived',hue='Sex', kind='point', data=df_train);

# %%
sns.catplot(x='Survived', col='Embarked', kind='count', data=df_train);

# %%
sns.catplot('Embarked','Survived', kind='point', data=df_train);

# %% [markdown]
# Embarked and Sex

# %%
sns.catplot('Embarked','Survived', hue= 'Sex', kind='point', data=df_train);

# %% [markdown]
# Embarked, Pclass and Sex :
#
# Practically all women of Pclass 2 that embarked in C and Q survived, also nearly all women of Pclass 1 survived.
#
# All men of Pclass 1 and 2 embarked in Q died, survival rate for men in Pclass 2 and 3 is always below 0.2
#
# For the remaining men in Pclass 1 that embarked in S and Q, survival rate is approx. 0.4

# %%
sns.catplot('Embarked','Survived', col='Pclass', hue= 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Survived], [df_train.Sex, df_train.Pclass, df_train.Embarked], margins=True)
# Out:
# Sex      female                              male                            \
# Pclass        1         2          3            1          2          3
# Embarked      C  Q   S  C  Q   S   C   Q   S    C  Q   S   C  Q   S   C   Q
# Survived
# 0             1  0   2  0  0   6   8   9  55   25  1  51   8  1  82  33  36
# 1            42  1  46  7  2  61  15  24  33   17  0  28   2  0  15  10   3
# All          43  1  48  7  2  67  23  33  88   42  1  79  10  1  97  43  39
#
# Sex            All
# Pclass
# Embarked    S
# Survived
# 0         231  549
# 1          34  340
# All       265  889

# %% [markdown]
# third model : based on PClass, Sex and Embarked , submission : 0.779 accuracy

# %%
# model 3
df_test['Survived'] = 0
# all women survived
df_test.loc[ (df_test.Sex == 'female'), 'Survived'] = 1
# except for those in Pclass 3 and embarked in S
df_test.loc[ (df_test.Sex == 'female') & (df_test.Pclass == 3) & (df_test.Embarked == 'S') , 'Survived'] = 0
#df_test[['PassengerId', 'Survived']].to_csv('embarked_pclass_sex.csv', index=False)

# %% [markdown]
# Age: continuous numerical to 8 bins

# %%
for df in [df_train, df_test]:
    df['Age_bin']=np.nan
    for i in range(8,0,-1):
        df.loc[ df['Age'] <= i*10, 'Age_bin'] = i

# %%
print(df_train[['Age' , 'Age_bin']].head(10))
# Out:
#     Age  Age_bin
# 0  22.0      3.0
# 1  38.0      4.0
# 2  26.0      3.0
# 3  35.0      4.0
# 4  35.0      4.0
# 5   NaN      NaN
# 6  54.0      6.0
# 7   2.0      1.0
# 8  27.0      3.0
# 9  14.0      2.0

# %%
sns.catplot('Age_bin','Survived',hue='Sex',kind='point',data=df_train);

# %%
sns.catplot('Age_bin','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Age_bin, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_220ca_row0_col0,#T_220ca_row1_col20,#T_220ca_row3_col19,#T_220ca_row3_col21{
#             background-color:  #ffaa00;
#             color:  #000000;
#         }#T_220ca_row0_col1,#T_220ca_row0_col3,#T_220ca_row0_col4,#T_220ca_row0_col6,#T_220ca_row0_col9,#T_220ca_row0_col10,#T_220ca_row0_col12,#T_220ca_row0_col13,#T_220ca_row0_col15,#T_220ca_row0_col17,#T_220ca_row0_col18,#T_220ca_row0_col19,#T_220ca_row0_col20,#T_220ca_row0_col21,#T_220ca_row0_col22,#T_220ca_row0_col23,#T_220ca_row1_col0,#T_220ca_row1_col11,#T_220ca_row1_col14,#T_220ca_row1_col17,#T_220ca_row1_col19,#T_220ca_row1_col21,#T_220ca_row1_col22,#T_220ca_row2_col0,#T_220ca_row2_col1,#T_220ca_row3_col2,#T_220ca_row3_col5,#T_220ca_row3_col7,#T_220ca_row3_col8,#T_220ca_row3_col13,#T_220ca_row3_col16,#T_220ca_row3_col17,#T_220ca_row3_col18,#T_220ca_row3_col20,#T_220ca_row3_col22{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_220ca_row0_col2,#T_220ca_row0_col16,#T_220ca_row1_col2,#T_220ca_row1_col5{
#             background-color:  #ffea00;
#             color:  #000000;
#         }#T_220ca_row0_col5,#T_220ca_row3_col14{
#             background-color:  #ffee00;
#             color:  #000000;
#         }#T_220ca_row0_col7,#T_220ca_row3_col10{
#             background-color:  #fff300;
#             color:  #000000;
#         }#T_220ca_row0_col8,#T_220ca_row1_col8,#T_220ca_row3_col11{
#             background-color:  #fffb00;
#             color:  #000000;
#         }#T_220ca_row0_col11{
#             background-color:  #fff700;
#             color:  #000000;
#         }#T_220ca_row0_col14{
#             background-color:  #ffbb00;
#             color:  #000000;
#         }#T_220ca_row1_col1{
#             background-color:  #ff8700;
#             color:  #000000;
#         }#T_220ca_row1_col3{
#             background-color:  #ff4700;
#             color:  #f1f1f1;
#         }#T_220ca_row1_col4,#T_220ca_row1_col13{
#             background-color:  #ff8e00;
#             color:  #000000;
#         }#T_220ca_row1_col6{
#             background-color:  #ff8300;
#             color:  #000000;
#         }#T_220ca_row1_col7{
#             background-color:  #ff9700;
#             color:  #000000;
#         }#T_220ca_row1_col9{
#             background-color:  #ff8200;
#             color:  #000000;
#         }#T_220ca_row1_col10{
#             background-color:  #ffa400;
#             color:  #000000;
#         }#T_220ca_row1_col12{
#             background-color:  #ffb100;
#             color:  #000000;
#         }#T_220ca_row1_col15{
#             background-color:  #ff8f00;
#             color:  #000000;
#         }#T_220ca_row1_col16,#T_220ca_row2_col2,#T_220ca_row2_col3{
#             background-color:  #ffd500;
#             color:  #000000;
#         }#T_220ca_row1_col18{
#             background-color:  #ffd100;
#             color:  #000000;
#         }#T_220ca_row1_col23,#T_220ca_row3_col6{
#             background-color:  #ffcb00;
#             color:  #000000;
#         }#T_220ca_row2_col4{
#             background-color:  #ff7f00;
#             color:  #000000;
#         }#T_220ca_row2_col5{
#             background-color:  #ff7100;
#             color:  #000000;
#         }#T_220ca_row2_col6{
#             background-color:  #ffc400;
#             color:  #000000;
#         }#T_220ca_row2_col7{
#             background-color:  #ff7500;
#             color:  #000000;
#         }#T_220ca_row2_col8{
#             background-color:  #ff6600;
#             color:  #000000;
#         }#T_220ca_row2_col9{
#             background-color:  #ffc100;
#             color:  #000000;
#         }#T_220ca_row2_col10{
#             background-color:  #ff7900;
#             color:  #000000;
#         }#T_220ca_row2_col11{
#             background-color:  #ff5e00;
#             color:  #000000;
#         }#T_220ca_row2_col12,#T_220ca_row2_col13{
#             background-color:  #ff9c00;
#             color:  #000000;
#         }#T_220ca_row2_col14,#T_220ca_row2_col19,#T_220ca_row2_col20,#T_220ca_row2_col21,#T_220ca_row3_col0{
#             background-color:  #ff5500;
#             color:  #000000;
#         }#T_220ca_row2_col15{
#             background-color:  #ff9900;
#             color:  #000000;
#         }#T_220ca_row2_col16{
#             background-color:  #ff3f00;
#             color:  #f1f1f1;
#         }#T_220ca_row2_col17,#T_220ca_row2_col22,#T_220ca_row4_col0,#T_220ca_row4_col1,#T_220ca_row4_col2,#T_220ca_row4_col3,#T_220ca_row4_col4,#T_220ca_row4_col5,#T_220ca_row4_col6,#T_220ca_row4_col7,#T_220ca_row4_col8,#T_220ca_row4_col9,#T_220ca_row4_col10,#T_220ca_row4_col11,#T_220ca_row4_col12,#T_220ca_row4_col13,#T_220ca_row4_col14,#T_220ca_row4_col15,#T_220ca_row4_col16,#T_220ca_row4_col17,#T_220ca_row4_col18,#T_220ca_row4_col19,#T_220ca_row4_col20,#T_220ca_row4_col21,#T_220ca_row4_col22,#T_220ca_row4_col23{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_220ca_row2_col18{
#             background-color:  #ff2e00;
#             color:  #f1f1f1;
#         }#T_220ca_row2_col23{
#             background-color:  #ff8b00;
#             color:  #000000;
#         }#T_220ca_row3_col1{
#             background-color:  #ff7800;
#             color:  #000000;
#         }#T_220ca_row3_col3{
#             background-color:  #ffe300;
#             color:  #000000;
#         }#T_220ca_row3_col4{
#             background-color:  #fff100;
#             color:  #000000;
#         }#T_220ca_row3_col9{
#             background-color:  #ffbc00;
#             color:  #000000;
#         }#T_220ca_row3_col12{
#             background-color:  #ffc700;
#             color:  #000000;
#         }#T_220ca_row3_col15{
#             background-color:  #ffd700;
#             color:  #000000;
#         }#T_220ca_row3_col23{
#             background-color:  #fff400;
#             color:  #000000;
#         }</style><table id="T_220ca_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Age_bin</th>        <th class="col_heading level0 col0" colspan="3">1.0</th>        <th class="col_heading level0 col3" colspan="3">2.0</th>        <th class="col_heading level0 col6" colspan="3">3.0</th>        <th class="col_heading level0 col9" colspan="3">4.0</th>        <th class="col_heading level0 col12" colspan="3">5.0</th>        <th class="col_heading level0 col15" colspan="3">6.0</th>        <th class="col_heading level0 col18" colspan="3">7.0</th>        <th class="col_heading level0 col21" colspan="2">8.0</th>        <th class="col_heading level0 col23" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Pclass</th>        <th class="col_heading level1 col0" >1</th>        <th class="col_heading level1 col1" >2</th>        <th class="col_heading level1 col2" >3</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" >2</th>        <th class="col_heading level1 col5" >3</th>        <th class="col_heading level1 col6" >1</th>        <th class="col_heading level1 col7" >2</th>        <th class="col_heading level1 col8" >3</th>        <th class="col_heading level1 col9" >1</th>        <th class="col_heading level1 col10" >2</th>        <th class="col_heading level1 col11" >3</th>        <th class="col_heading level1 col12" >1</th>        <th class="col_heading level1 col13" >2</th>        <th class="col_heading level1 col14" >3</th>        <th class="col_heading level1 col15" >1</th>        <th class="col_heading level1 col16" >2</th>        <th class="col_heading level1 col17" >3</th>        <th class="col_heading level1 col18" >1</th>        <th class="col_heading level1 col19" >2</th>        <th class="col_heading level1 col20" >3</th>        <th class="col_heading level1 col21" >1</th>        <th class="col_heading level1 col22" >3</th>        <th class="col_heading level1 col23" ></th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ><

# %% [markdown]
# For passengers in Age_bin = 1 (younger than 10) : All male in Pclass 1 and 2 survived
#
# All female in Pclass 3 and Age_bin = 5 died.
#
# (Survival rate for female in Pclass 3 and Age_bin = 4 is below 50%)
#
# (Survival rate for male in Pclass 1 and Age_bin = 4 is above 50%)

# %%
# in Pclass 1 and 2 all men in Age_bin = 1 survived
df_test.loc[ (df_test.Sex == 'male') & (df_test.Pclass == 1) & (df_test.Age_bin == 1), 'Survived'] = 1
df_test.loc[ (df_test.Sex == 'male') & (df_test.Pclass == 2) & (df_test.Age_bin == 1), 'Survived'] = 1

# %%
sns.catplot('SibSp','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.SibSp, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_80b76_row0_col0,#T_80b76_row0_col1,#T_80b76_row0_col2,#T_80b76_row0_col3,#T_80b76_row0_col4,#T_80b76_row0_col6,#T_80b76_row0_col7,#T_80b76_row0_col9,#T_80b76_row0_col10,#T_80b76_row0_col15,#T_80b76_row1_col13,#T_80b76_row1_col14,#T_80b76_row2_col10,#T_80b76_row3_col5,#T_80b76_row3_col8,#T_80b76_row3_col9,#T_80b76_row3_col10,#T_80b76_row3_col11,#T_80b76_row3_col12,#T_80b76_row3_col13,#T_80b76_row3_col14{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_80b76_row0_col5{
#             background-color:  #ffd900;
#             color:  #000000;
#         }#T_80b76_row0_col8{
#             background-color:  #ffdb00;
#             color:  #000000;
#         }#T_80b76_row0_col11{
#             background-color:  #ff6a00;
#             color:  #000000;
#         }#T_80b76_row0_col12{
#             background-color:  #ffd200;
#             color:  #000000;
#         }#T_80b76_row0_col13,#T_80b76_row2_col3,#T_80b76_row2_col6,#T_80b76_row3_col6{
#             background-color:  #ffcc00;
#             color:  #000000;
#         }#T_80b76_row0_col14,#T_80b76_row2_col0,#T_80b76_row2_col8{
#             background-color:  #ff9200;
#             color:  #000000;
#         }#T_80b76_row1_col0{
#             background-color:  #ffa700;
#             color:  #000000;
#         }#T_80b76_row1_col1,#T_80b76_row2_col4{
#             background-color:  #ffac00;
#             color:  #000000;
#         }#T_80b76_row1_col2{
#             background-color:  #fff300;
#             color:  #000000;
#         }#T_80b76_row1_col3{
#             background-color:  #ff7a00;
#             color:  #000000;
#         }#T_80b76_row1_col4{
#             background-color:  #ff9300;
#             color:  #000000;
#         }#T_80b76_row1_col5{
#             background-color:  #ffe700;
#             color:  #000000;
#         }#T_80b76_row1_col6{
#             background-color:  #ff6600;
#             color:  #000000;
#         }#T_80b76_row1_col7{
#             background-color:  #ff9f00;
#             color:  #000000;
#         }#T_80b76_row1_col8{
#             background-color:  #ffc900;
#             color:  #000000;
#         }#T_80b76_row1_col9{
#             background-color:  #ff5500;
#             color:  #000000;
#         }#T_80b76_row1_col10,#T_80b76_row4_col0,#T_80b76_row4_col1,#T_80b76_row4_col2,#T_80b76_row4_col3,#T_80b76_row4_col4,#T_80b76_row4_col5,#T_80b76_row4_col6,#T_80b76_row4_col7,#T_80b76_row4_col8,#T_80b76_row4_col9,#T_80b76_row4_col10,#T_80b76_row4_col11,#T_80b76_row4_col12,#T_80b76_row4_col13,#T_80b76_row4_col14,#T_80b76_row4_col15{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_80b76_row1_col11{
#             background-color:  #ffea00;
#             color:  #000000;
#         }#T_80b76_row1_col12{
#             background-color:  #fff000;
#             color:  #000000;
#         }#T_80b76_row1_col15,#T_80b76_row3_col3{
#             background-color:  #ffcf00;
#             color:  #000000;
#         }#T_80b76_row2_col1{
#             background-color:  #ff7300;
#             color:  #000000;
#         }#T_80b76_row2_col2{
#             background-color:  #ff5d00;
#             color:  #000000;
#         }#T_80b76_row2_col5{
#             background-color:  #ffa800;
#             color:  #000000;
#         }#T_80b76_row2_col7{
#             background-color:  #ff7f00;
#             color:  #000000;
#         }#T_80b76_row2_col9,#T_80b76_row2_col11{
#             background-color:  #ffaa00;
#             color:  #000000;
#         }#T_80b76_row2_col12{
#             background-color:  #ff6900;
#             color:  #000000;
#         }#T_80b76_row2_col13{
#             background-color:  #ff3300;
#             color:  #f1f1f1;
#         }#T_80b76_row2_col14{
#             background-color:  #ff6d00;
#             color:  #000000;
#         }#T_80b76_row2_col15{
#             background-color:  #ff8500;
#             color:  #000000;
#         }#T_80b76_row3_col0{
#             background-color:  #ffcb00;
#             color:  #000000;
#         }#T_80b76_row3_col1{
#             background-color:  #fff200;
#             color:  #000000;
#         }#T_80b76_row3_col2{
#             background-color:  #fffe00;
#             color:  #000000;
#         }#T_80b76_row3_col4{
#             background-color:  #ffec00;
#             color:  #000000;
#         }#T_80b76_row3_col7{
#             background-color:  #ffdf00;
#             color:  #000000;
#         }#T_80b76_row3_col15{
#             background-color:  #fff700;
#             color:  #000000;
#         }</style><table id="T_80b76_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >SibSp</th>        <th class="col_heading level0 col0" colspan="3">0</th>        <th class="col_heading level0 col3" colspan="3">1</th>        <th class="col_heading level0 col6" colspan="3">2</th>        <th class="col_heading level0 col9" colspan="3">3</th>        <th class="col_heading level0 col12" >4</th>        <th class="col_heading level0 col13" >5</th>        <th class="col_heading level0 col14" >8</th>        <th class="col_heading level0 col15" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Pclass</th>        <th class="col_heading level1 col0" >1</th>        <th class="col_heading level1 col1" >2</th>        <th class="col_heading level1 col2" >3</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" >2</th>        <th class="col_heading level1 col5" >3</th>        <th class="col_heading level1 col6" >1</th>        <th class="col_heading level1 col7" >2</th>        <th class="col_heading level1 col8" >3</th>        <th class="col_heading level1 col9" >1</th>        <th class="col_heading level1 col10" >2</th>        <th class="col_heading level1 col11" >3</th>        <th class="col_heading level1 col12" >3</th>        <th class="col_heading level1 col13" >3</th>        <th class="col_heading level1 col14" >3</th>        <th class="col_heading level1 col15" ></th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80b76_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#                         <th id="T_80b76_level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_80b76_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_80b76_row0_col1" class="data row0 col1" >3</td>
#                         <td id="T_80b76_row0_col2" class="data row0 col2" >33</td>
#                         <td id="T_80b76_row0_col3" class="data row0 col3" >2</td>
#                         <td id="T_80b76_row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_80b76_row0_col5" class="data row0 col5" >21</td>
#                         <td id="T_80b76_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_80b76_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_80b76_row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_80b76_row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_80b76_row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_80b76_row0_col11" class="data row0 col11" >7</td>
#                         <td id="T_80b76_row0_col12" class="data row0 col12" >4</td>
#                         <td id="T_80b76_row0_col13" class="data row0 col13" >1</td>
#                         <td id="T_80b76_ro

# %%
# all females with SibSp > 7 died
df_test.loc[ (df_test.Sex == 'female') & (df_test.SibSp > 7) , 'Survived'] = 0

# %%
sns.catplot('Parch','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Parch, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_239a1_row0_col0,#T_239a1_row0_col1,#T_239a1_row0_col2,#T_239a1_row0_col3,#T_239a1_row0_col4,#T_239a1_row0_col6,#T_239a1_row0_col7,#T_239a1_row0_col9,#T_239a1_row0_col11,#T_239a1_row0_col15,#T_239a1_row1_col11,#T_239a1_row1_col12,#T_239a1_row1_col14,#T_239a1_row2_col9,#T_239a1_row2_col14,#T_239a1_row3_col2,#T_239a1_row3_col5,#T_239a1_row3_col8,#T_239a1_row3_col9,#T_239a1_row3_col10,#T_239a1_row3_col11,#T_239a1_row3_col12,#T_239a1_row3_col13,#T_239a1_row3_col14{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_239a1_row0_col5{
#             background-color:  #ffe400;
#             color:  #000000;
#         }#T_239a1_row0_col8{
#             background-color:  #ffa600;
#             color:  #000000;
#         }#T_239a1_row0_col10,#T_239a1_row1_col10,#T_239a1_row2_col10,#T_239a1_row2_col12{
#             background-color:  #ffaa00;
#             color:  #000000;
#         }#T_239a1_row0_col12{
#             background-color:  #ff5500;
#             color:  #000000;
#         }#T_239a1_row0_col13{
#             background-color:  #ff6600;
#             color:  #000000;
#         }#T_239a1_row0_col14,#T_239a1_row1_col9,#T_239a1_row2_col11,#T_239a1_row4_col0,#T_239a1_row4_col1,#T_239a1_row4_col2,#T_239a1_row4_col3,#T_239a1_row4_col4,#T_239a1_row4_col5,#T_239a1_row4_col6,#T_239a1_row4_col7,#T_239a1_row4_col8,#T_239a1_row4_col9,#T_239a1_row4_col10,#T_239a1_row4_col11,#T_239a1_row4_col12,#T_239a1_row4_col13,#T_239a1_row4_col14,#T_239a1_row4_col15{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_239a1_row1_col0,#T_239a1_row2_col0{
#             background-color:  #ff9e00;
#             color:  #000000;
#         }#T_239a1_row1_col1{
#             background-color:  #ffba00;
#             color:  #000000;
#         }#T_239a1_row1_col2{
#             background-color:  #fff400;
#             color:  #000000;
#         }#T_239a1_row1_col3{
#             background-color:  #ff7300;
#             color:  #000000;
#         }#T_239a1_row1_col4{
#             background-color:  #ff7b00;
#             color:  #000000;
#         }#T_239a1_row1_col5{
#             background-color:  #ffea00;
#             color:  #000000;
#         }#T_239a1_row1_col6{
#             background-color:  #ff8600;
#             color:  #000000;
#         }#T_239a1_row1_col7{
#             background-color:  #ff4f00;
#             color:  #000000;
#         }#T_239a1_row1_col8,#T_239a1_row3_col7{
#             background-color:  #ffdf00;
#             color:  #000000;
#         }#T_239a1_row1_col13,#T_239a1_row2_col13{
#             background-color:  #ffcc00;
#             color:  #000000;
#         }#T_239a1_row1_col15,#T_239a1_row2_col7{
#             background-color:  #ffcf00;
#             color:  #000000;
#         }#T_239a1_row2_col1{
#             background-color:  #ff6900;
#             color:  #000000;
#         }#T_239a1_row2_col2{
#             background-color:  #ff5900;
#             color:  #000000;
#         }#T_239a1_row2_col3{
#             background-color:  #ffad00;
#             color:  #000000;
#         }#T_239a1_row2_col4,#T_239a1_row3_col4{
#             background-color:  #ffce00;
#             color:  #000000;
#         }#T_239a1_row2_col5,#T_239a1_row2_col8{
#             background-color:  #ffb300;
#             color:  #000000;
#         }#T_239a1_row2_col6{
#             background-color:  #fff200;
#             color:  #000000;
#         }#T_239a1_row2_col15{
#             background-color:  #ff8500;
#             color:  #000000;
#         }#T_239a1_row3_col0{
#             background-color:  #ffc800;
#             color:  #000000;
#         }#T_239a1_row3_col1{
#             background-color:  #fffa00;
#             color:  #000000;
#         }#T_239a1_row3_col3{
#             background-color:  #ffde00;
#             color:  #000000;
#         }#T_239a1_row3_col6{
#             background-color:  #ffd700;
#             color:  #000000;
#         }#T_239a1_row3_col15{
#             background-color:  #fff700;
#             color:  #000000;
#         }</style><table id="T_239a1_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Parch</th>        <th class="col_heading level0 col0" colspan="3">0</th>        <th class="col_heading level0 col3" colspan="3">1</th>        <th class="col_heading level0 col6" colspan="3">2</th>        <th class="col_heading level0 col9" colspan="2">3</th>        <th class="col_heading level0 col11" colspan="2">4</th>        <th class="col_heading level0 col13" >5</th>        <th class="col_heading level0 col14" >6</th>        <th class="col_heading level0 col15" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Pclass</th>        <th class="col_heading level1 col0" >1</th>        <th class="col_heading level1 col1" >2</th>        <th class="col_heading level1 col2" >3</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" >2</th>        <th class="col_heading level1 col5" >3</th>        <th class="col_heading level1 col6" >1</th>        <th class="col_heading level1 col7" >2</th>        <th class="col_heading level1 col8" >3</th>        <th class="col_heading level1 col9" >2</th>        <th class="col_heading level1 col10" >3</th>        <th class="col_heading level1 col11" >1</th>        <th class="col_heading level1 col12" >3</th>        <th class="col_heading level1 col13" >3</th>        <th class="col_heading level1 col14" >3</th>        <th class="col_heading level1 col15" ></th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_239a1_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#                         <th id="T_239a1_level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_239a1_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_239a1_row0_col1" class="data row0 col1" >5</td>
#                         <td id="T_239a1_row0_col2" class="data row0 col2" >35</td>
#                         <td id="T_239a1_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_239a1_row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_239a1_row0_col5" class="data row0 col5" >13</td>
#                         <td id="T_239a1_row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_239a1_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_239a1_row0_col8" class="data row0 col8" >17</td>
#                         <td id="T_239a1_row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_239a1_row0_col10" class="data row0 col10" >1</td>
#                         <td id="T_239a1_row0_col11" class="data row0 col11" >0</td>
#                         <td id="T_239a1_row0_col12" class="data row0 col12" >2</td>
#                         <td id="T_239a1_row0_col13" class="data row0 col13" >3</td>
#                         <td id="T_239a1_row0_col14" class="data row0 col14" >1</td>
#                         <td id="T_239a1_row0_col15" class="data row0 col15" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_239a1_level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_239a1_row1_col0" class="data row1 col0" >63</td>
#                         <td id="T_239a1_row1_col1" class="data row1 col1" >40</td>
#                         <td id="T

# %%
sns.distplot(df_train['Fare']);

# %%
for df in [df_train, df_test]:
    df['Fare_bin']=np.nan
    for i in range(12,0,-1):
        df.loc[ df['Fare'] <= i*50, 'Fare_bin'] = i

# %%
sns.catplot('Fare_bin','Survived', col='Pclass' , row = 'Sex', kind='point', data=df_train);

# %%
pd.crosstab([df_train.Sex, df_train.Survived], [df_train.Fare_bin, df_train.Pclass], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
# #T_f6086_row0_col0,#T_f6086_row0_col1,#T_f6086_row0_col3,#T_f6086_row0_col4,#T_f6086_row0_col6,#T_f6086_row0_col8,#T_f6086_row0_col9,#T_f6086_row0_col10,#T_f6086_row0_col11,#T_f6086_row1_col5,#T_f6086_row2_col7,#T_f6086_row2_col10,#T_f6086_row3_col2,#T_f6086_row3_col4,#T_f6086_row3_col7,#T_f6086_row3_col8,#T_f6086_row3_col9{
#             background-color:  #ffff00;
#             color:  #000000;
#         }#T_f6086_row0_col2{
#             background-color:  #fff000;
#             color:  #000000;
#         }#T_f6086_row0_col5{
#             background-color:  #ffc900;
#             color:  #000000;
#         }#T_f6086_row0_col7{
#             background-color:  #ffdf00;
#             color:  #000000;
#         }#T_f6086_row1_col0{
#             background-color:  #ffde00;
#             color:  #000000;
#         }#T_f6086_row1_col1{
#             background-color:  #ffa300;
#             color:  #000000;
#         }#T_f6086_row1_col2{
#             background-color:  #ffee00;
#             color:  #000000;
#         }#T_f6086_row1_col3{
#             background-color:  #ff7100;
#             color:  #000000;
#         }#T_f6086_row1_col4{
#             background-color:  #ffb600;
#             color:  #000000;
#         }#T_f6086_row1_col6{
#             background-color:  #ff5f00;
#             color:  #000000;
#         }#T_f6086_row1_col7{
#             background-color:  #ff7f00;
#             color:  #000000;
#         }#T_f6086_row1_col8{
#             background-color:  #ff5d00;
#             color:  #000000;
#         }#T_f6086_row1_col9,#T_f6086_row3_col10{
#             background-color:  #ff5500;
#             color:  #000000;
#         }#T_f6086_row1_col10,#T_f6086_row2_col9{
#             background-color:  #ffaa00;
#             color:  #000000;
#         }#T_f6086_row1_col11{
#             background-color:  #ffcf00;
#             color:  #000000;
#         }#T_f6086_row2_col0{
#             background-color:  #ff7500;
#             color:  #000000;
#         }#T_f6086_row2_col1{
#             background-color:  #ff8800;
#             color:  #000000;
#         }#T_f6086_row2_col2{
#             background-color:  #ff6b00;
#             color:  #000000;
#         }#T_f6086_row2_col3{
#             background-color:  #ffbb00;
#             color:  #000000;
#         }#T_f6086_row2_col4{
#             background-color:  #ff4900;
#             color:  #000000;
#         }#T_f6086_row2_col5{
#             background-color:  #ff9200;
#             color:  #000000;
#         }#T_f6086_row2_col6{
#             background-color:  #ffca00;
#             color:  #000000;
#         }#T_f6086_row2_col8{
#             background-color:  #ffa200;
#             color:  #000000;
#         }#T_f6086_row2_col11{
#             background-color:  #ff8500;
#             color:  #000000;
#         }#T_f6086_row3_col0{
#             background-color:  #ffb500;
#             color:  #000000;
#         }#T_f6086_row3_col1{
#             background-color:  #ffef00;
#             color:  #000000;
#         }#T_f6086_row3_col3{
#             background-color:  #ffd300;
#             color:  #000000;
#         }#T_f6086_row3_col5{
#             background-color:  #ffa400;
#             color:  #000000;
#         }#T_f6086_row3_col6{
#             background-color:  #ffd500;
#             color:  #000000;
#         }#T_f6086_row3_col11{
#             background-color:  #fff700;
#             color:  #000000;
#         }#T_f6086_row4_col0,#T_f6086_row4_col1,#T_f6086_row4_col2,#T_f6086_row4_col3,#T_f6086_row4_col4,#T_f6086_row4_col5,#T_f6086_row4_col6,#T_f6086_row4_col7,#T_f6086_row4_col8,#T_f6086_row4_col9,#T_f6086_row4_col10,#T_f6086_row4_col11{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_f6086_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Fare_bin</th>        <th class="col_heading level0 col0" colspan="3">1.0</th>        <th class="col_heading level0 col3" colspan="3">2.0</th>        <th class="col_heading level0 col6" >3.0</th>        <th class="col_heading level0 col7" >4.0</th>        <th class="col_heading level0 col8" >5.0</th>        <th class="col_heading level0 col9" >6.0</th>        <th class="col_heading level0 col10" >11.0</th>        <th class="col_heading level0 col11" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Pclass</th>        <th class="col_heading level1 col0" >1</th>        <th class="col_heading level1 col1" >2</th>        <th class="col_heading level1 col2" >3</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" >2</th>        <th class="col_heading level1 col5" >3</th>        <th class="col_heading level1 col6" >1</th>        <th class="col_heading level1 col7" >1</th>        <th class="col_heading level1 col8" >1</th>        <th class="col_heading level1 col9" >1</th>        <th class="col_heading level1 col10" >1</th>        <th class="col_heading level1 col11" ></th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6086_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#                         <th id="T_f6086_level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_f6086_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_f6086_row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_f6086_row0_col2" class="data row0 col2" >69</td>
#                         <td id="T_f6086_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_f6086_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_f6086_row0_col5" class="data row0 col5" >3</td>
#                         <td id="T_f6086_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_f6086_row0_col7" class="data row0 col7" >2</td>
#                         <td id="T_f6086_row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_f6086_row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_f6086_row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_f6086_row0_col11" class="data row0 col11" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_f6086_level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_f6086_row1_col0" class="data row1 col0" >11</td>
#                         <td id="T_f6086_row1_col1" class="data row1 col1" >68</td>
#                         <td id="T_f6086_row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_f6086_row1_col3" class="data row1 col3" >48</td>
#                         <td id="T_f6086_row1_col4" class="data row1 col4" >2</td>
#                         <td id="T_f6086_row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_f6086_row1_col6" class="data row1 col6" >15</td>
#                         <td id="T_f6086_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_f6086_row1_col8" class="data row1 col8" >7</td>
#                         <td id="T_f6086_row1_col9" class="data row1 col9" >4</td>
#                         <td id="T_f6086_row1_col10" class="data row1 col10" >1</td>
#                         <td id="T_f6086_row1_col11" class="data row1 col11" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_f6086_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#                         <th id="T_f6086_level1_row2" class="row_heading le

# %%
# males in Fare_bin = 11 survived
df_test.loc[ (df_test.Sex == 'male') & (df_test.Fare_bin == 11), 'Survived'] = 1

# %%
df_test.drop(['Survived'],axis=1,inplace=True)

# %% [markdown]
# **Data wrangling**

# %%
df_train_ml = df_train.copy()
df_test_ml = df_test.copy()

# %%
df_train_ml = pd.get_dummies(df_train_ml, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
df_train_ml.drop(['PassengerId','Name','Ticket', 'Cabin', 'Age_bin', 'Fare_bin'],axis=1,inplace=True)
df_train_ml.dropna(inplace=True)

# %%
passenger_id = df_test_ml['PassengerId']
df_test_ml = pd.get_dummies(df_test_ml, columns=['Sex', 'Embarked', 'Pclass'], drop_first=True)
df_test_ml.drop(['PassengerId','Name','Ticket', 'Cabin', 'Age_bin', 'Fare_bin'],axis=1,inplace=True)

# %%
df_train_ml.head(10)
# Out:
#     Survived   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S  \
# 0          0  22.0      1      0   7.2500         1           0           1
# 1          1  38.0      1      0  71.2833         0           0           0
# 2          1  26.0      0      0   7.9250         0           0           1
# 3          1  35.0      1      0  53.1000         0           0           1
# 4          0  35.0      0      0   8.0500         1           0           1
# 6          0  54.0      0      0  51.8625         1           0           1
# 7          0   2.0      3      1  21.0750         1           0           1
# 8          1  27.0      0      2  11.1333         0           0           1
# 9          1  14.0      1      0  30.0708         0           0           0
# 10         1   4.0      1      1  16.7000         0           0           1
#
#     Pclass_2  Pclass_3
# 0          0         1
# 1          0         0
# 2          0         1
# 3          0         0
# 4          0         1
# 6          0         0
# 7          0         1
# 8          0         1
# 9          1         0
# 10         0         1

# %%
df_train_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    714 non-null    int64
#  1   Age         714 non-null    float64
#  2   SibSp       714 non-null    int64
#  3   Parch       714 non-null    int64
#  4   Fare        714 non-null    float64
#  5   Sex_male    714 non-null    uint8
#  6   Embarked_Q  714 non-null    uint8
#  7   Embarked_S  714 non-null    uint8
#  8   Pclass_2    714 non-null    uint8
#  9   Pclass_3    714 non-null    uint8
# dtypes: float64(2), int64(3), uint8(5)
# memory usage: 37.0 KB

# %%
df_test_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         332 non-null    float64
#  1   SibSp       418 non-null    int64
#  2   Parch       418 non-null    int64
#  3   Fare        417 non-null    float64
#  4   Sex_male    418 non-null    uint8
#  5   Embarked_Q  418 non-null    uint8
#  6   Embarked_S  418 non-null    uint8
#  7   Pclass_2    418 non-null    uint8
#  8   Pclass_3    418 non-null    uint8
# dtypes: float64(2), int64(2), uint8(5)
# memory usage: 15.2 KB

# %%
df_test_ml.head(10)
# Out:
#     Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  Embarked_S  Pclass_2  \
# 0  34.5      0      0   7.8292         1           1           0         0
# 1  47.0      1      0   7.0000         0           0           1         0
# 2  62.0      0      0   9.6875         1           1           0         1
# 3  27.0      0      0   8.6625         1           0           1         0
# 4  22.0      1      1  12.2875         0           0           1         0
# 5  14.0      0      0   9.2250         1           0           1         0
# 6  30.0      0      0   7.6292         0           1           0         0
# 7  26.0      1      1  29.0000         1           0           1         1
# 8  18.0      0      0   7.2292         0           0           0         0
# 9  21.0      2      0  24.1500         1           0           1         0
#
#    Pclass_3
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1
# 5         1
# 6         1
# 7         0
# 8         1
# 9         1

# %% [markdown]
# **Correlation Matrix**

# %%
corr = df_train_ml.corr()

f,ax = plt.subplots(figsize=(9,6))
sns.heatmap(corr, annot = True, linewidths=1.5 , fmt = '.2f',ax=ax)
plt.show()
