# %% [markdown]
# # Assignment/Task 5
#
# ## GO_STP_2
#
# #### Task Link : https://www.goeduhub.com/11547/question-exercise-practice-solutions-science-machine-learning

# %% [markdown]
# #### 1. Load the IMDb Dataset and read

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("IMDB-Movie-Data.csv")

# %% [markdown]
# #### 2. View the dataset

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# #### 3. Understand some basic information about the dataset and Inspect the dataframe Inspect the dataframe's columns, shapes, variable types etc.

# %%
df.size
# Out:
# 12000

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#         'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#         'Metascore'],
#        dtype='object')]

# %%
df.values
# Out:
# array([[1, 'Guardians of the Galaxy', 'Action,Adventure,Sci-Fi', ...,
#         757074, 333.13, 76.0],
#        [2, 'Prometheus', 'Adventure,Mystery,Sci-Fi', ..., 485820, 126.46,
#         65.0],
#        [3, 'Split', 'Horror,Thriller', ..., 157606, 138.12, 62.0],
#        ...,
#        [998, 'Step Up 2: The Streets', 'Drama,Music,Romance', ..., 70699,
#         58.01, 50.0],
#        [999, 'Search Party', 'Adventure,Comedy', ..., 4881, nan, 22.0],
#        [1000, 'Nine Lives', 'Comedy,Family,Fantasy', ..., 12435, 19.64,
#         11.0]], dtype=object)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
df['Actors']
# Out:
# 0      Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1      Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2      James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3      Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4      Will Smith, Jared Leto, Margot Robbie, Viola D...
#                              ...
# 995    Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996    Lauren German, Heather Matarazzo, Bijou Philli...
# 997    Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998    Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# 999    Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# Name: Actors, Length: 1000, dtype: object

# %%
df[['Rank']].describe
# Out:
# <bound method NDFrame.describe of      Rank
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 995   996
# 996   997
# 997   998
# 998   999
# 999  1000
#
# [1000 rows x 1 columns]>

# %%
df['Title'].describe
# Out:
# <bound method NDFrame.describe of 0      Guardians of the Galaxy
# 1                   Prometheus
# 2                        Split
# 3                         Sing
# 4                Suicide Squad
#                 ...
# 995       Secret in Their Eyes
# 996            Hostel: Part II
# 997     Step Up 2: The Streets
# 998               Search Party
# 999                 Nine Lives
# Name: Title, Length: 1000, dtype: object>

# %% [markdown]
# #### 4. Data Selection – Indexing and Slicing data

# %%
df[['Genre', 'Revenue (Millions)']]
# Out:
#                         Genre  Revenue (Millions)
# 0     Action,Adventure,Sci-Fi              333.13
# 1    Adventure,Mystery,Sci-Fi              126.46
# 2             Horror,Thriller              138.12
# 3     Animation,Comedy,Family              270.32
# 4    Action,Adventure,Fantasy              325.02
# ..                        ...                 ...
# 995       Crime,Drama,Mystery                 NaN
# 996                    Horror               17.54
# 997       Drama,Music,Romance               58.01
# 998          Adventure,Comedy                 NaN
# 999     Comedy,Family,Fantasy               19.64
#
# [1000 rows x 2 columns]

# %%
df[34:43]
# Out:
#     Rank                             Title                       Genre  \
# 34    35  Resident Evil: The Final Chapter        Action,Horror,Sci-Fi
# 35    36        Captain America: Civil War     Action,Adventure,Sci-Fi
# 36    37                      Interstellar      Adventure,Drama,Sci-Fi
# 37    38                    Doctor Strange    Action,Adventure,Fantasy
# 38    39             The Magnificent Seven    Action,Adventure,Western
# 39    40                         5- 25- 77                Comedy,Drama
# 40    41                     Sausage Party  Animation,Adventure,Comedy
# 41    42                         Moonlight                       Drama
# 42    43           Don't Fuck in the Woods                      Horror
#
#                                           Description              Director  \
# 34  Alice returns to where the nightmare began: Th...    Paul W.S. Anderson
# 35  Political interference in the Avengers' activi...         Anthony Russo
# ...

# %%
df.iloc[23:25, 1:3]
# Out:
#                            Title                       Genre
# 23                        Trolls  Animation,Adventure,Comedy
# 24  Independence Day: Resurgence     Action,Adventure,Sci-Fi

# %% [markdown]
# #### 5. Data Selection – Based on Conditional filtering

# %%
df.loc[10:20, ['Year', 'Actors', 'Rating', 'Year']]
# Out:
#     Year                                             Actors  Rating  Year
# 10  2016  Eddie Redmayne, Katherine Waterston, Alison Su...     7.5  2016
# 11  2016  Taraji P. Henson, Octavia Spencer, Janelle Mon...     7.8  2016
# 12  2016  Felicity Jones, Diego Luna, Alan Tudyk, Donnie...     7.9  2016
# 13  2016  Auli'i Cravalho, Dwayne Johnson, Rachel House,...     7.7  2016
# 14  2016  Anne Hathaway, Jason Sudeikis, Austin Stowell,...     6.4  2016
# 15  2016  Louis C.K., Eric Stonestreet, Kevin Hart, Lake...     6.6  2016
# 16  2016  Andrew Garfield, Sam Worthington, Luke Bracey,...     8.2  2016
# 17  2016  Matt Damon, Tommy Lee Jones, Alicia Vikander,V...     6.7  2016
# 18  2016  Dev Patel, Nicole Kidman, Rooney Mara, Sunny P...     8.1  2016
# 19  2016  Amy Adams, Jeremy Renner, Forest Whitaker,Mich...     8.0  2016
# 20  2016  Matthew McConaughey, Edgar Ramírez, Bryce Dall...     6.7  2016

# %% [markdown]
#  #### 6. Groupby operations

# %%
df_a = df.groupby('Year')

# %%
df_a.mean()
# Out:
#             Rank  Runtime (Minutes)    Rating          Votes  \
# Year
# 2006  588.500000         120.840909  7.125000  269289.954545
# 2007  576.584906         121.622642  7.133962  244331.037736
# 2008  625.634615         110.826923  6.784615  275505.384615
# 2009  586.823529         116.117647  6.960784  255780.647059
# 2010  587.316667         111.133333  6.826667  252782.316667
# 2011  589.571429         114.603175  6.838095  240790.301587
# 2012  532.875000         119.109375  6.925000  285226.093750
# 2013  556.230769         116.065934  6.812088  219049.648352
# 2014  512.979592         114.489796  6.837755  203930.224490
# 2015  491.393701         114.496063  6.602362  115726.220472
# 2016  376.444444         107.373737  6.436700   48591.754209
#
#       Revenue (Millions)  Metascore
# Year
# 2006           86.296667  64.414634
# 2007           87.882245  64.500000
# 2008           99.082745  57.408163
# 2009          112.601277  57.122449
# ...

# %%
g = df.groupby('Revenue (Millions)')
g[['Votes']].mean()
# Out:
#                            Votes
# Revenue (Millions)
# 0.00                3.305000e+03
# 0.01                1.841300e+04
# 0.02                2.543700e+04
# 0.03                3.070714e+04
# 0.04                1.850400e+04
# ...                          ...
# 533.32              1.791916e+06
# 623.28              1.045588e+06
# 652.18              4.551690e+05
# 760.51              9.354080e+05
# 936.63              6.616080e+05
#
# [814 rows x 1 columns]

# %% [markdown]
# #### 7.Sorting operation

# %%
df_sort = df.sort_values(by = 'Year')
df_sort.head()
# Out:
#      Rank              Title                     Genre  \
# 773   774  Lady in the Water     Drama,Fantasy,Mystery
# 445   446        Silent Hill  Adventure,Horror,Mystery
# 99    100       The Departed      Crime,Drama,Thriller
# 550   551       The Break-Up      Comedy,Drama,Romance
# 885   886              Babel                     Drama
#
#                                            Description  \
# 773  Apartment building superintendent Cleveland He...
# 445  A woman, Rose, goes in search for her adopted ...
# 99   An undercover cop and a mole in the police att...
# 550  In a bid to keep their luxurious condo from th...
# 885  Tragedy strikes a married couple on vacation i...
#
#                         Director  \
# 773           M. Night Shyamalan
# 445              Christophe Gans
# 99               Martin Scorsese
# 550                  Peyton Reed
# 885  Alejandro González Iñárritu
#
#                                                 Actors  Year  \
# ...

# %%
df.sort_index(ascending= True)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.sort_values(by=['Rating', 'Year', 'Revenue (Millions)'] , ascending= [True, False, False])
# Out:
#      Rank                    Title                     Genre  \
# 829   830           Disaster Movie                    Comedy
# 42     43  Don't Fuck in the Woods                    Horror
# 871   872     Dragonball Evolution  Action,Adventure,Fantasy
# 647   648                 Tall Men   Fantasy,Horror,Thriller
# 890   891               The Intent               Crime,Drama
# ..    ...                      ...                       ...
# 36     37             Interstellar    Adventure,Drama,Sci-Fi
# 249   250         The Intouchables    Biography,Comedy,Drama
# 117   118                   Dangal    Action,Biography,Drama
# 80     81                Inception   Action,Adventure,Sci-Fi
# 54     55          The Dark Knight        Action,Crime,Drama
#
#                                            Description           Director  \
# 829  Over the course of one evening, an unsuspectin...    Jason Friedberg
# 42   A group of friends are going on a camping trip...      Shawn Burkett
# ...

# %% [markdown]
# #### 8.Dealing with missing values

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
print(df.isnull().values.any())
# Out:
# True

# %%
print(df.isnull().sum())
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# #### 9. Dropping columns and null values

# %%
df.dropna(axis=0,inplace=True)

# %%
df['Metascore'].fillna(0, inplace=True)

# %%
df['Revenue (Millions)'].fillna(0, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# #### 10. Apply( ) functions

# %%
def percent(n):
    return n*1000/100

# %%
df.Rating.apply(percent)
# Out:
# 0      81.0
# 1      70.0
# 2      73.0
# 3      72.0
# 4      62.0
#        ...
# 993    59.0
# 994    67.0
# 996    55.0
# 997    62.0
# 999    53.0
# Name: Rating, Length: 838, dtype: float64

# %%
df[['Rating', 'Runtime (Minutes)','Votes','Revenue (Millions)',
'Metascore']].apply(percent)
# Out:
#      Rating  Runtime (Minutes)      Votes  Revenue (Millions)  Metascore
# 0      81.0             1210.0  7570740.0              3331.3      760.0
# 1      70.0             1240.0  4858200.0              1264.6      650.0
# 2      73.0             1170.0  1576060.0              1381.2      620.0
# 3      72.0             1080.0   605450.0              2703.2      590.0
# 4      62.0             1230.0  3937270.0              3250.2      400.0
# ..      ...                ...        ...                 ...        ...
# 993    59.0              970.0  1409000.0               601.3      370.0
# 994    67.0              880.0  1640880.0               547.2      480.0
# 996    55.0              940.0   731520.0               175.4      460.0
# 997    62.0              980.0   706990.0               580.1      500.0
# 999    53.0              870.0   124350.0               196.4      110.0
#
# [838 rows x 5 columns]
